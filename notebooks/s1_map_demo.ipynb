# %%
from sharpness.spec_slope import s1_map
from sharpness.dataloader import load_data
import matplotlib.pyplot as plt

# %%
img = load_data('../data/kh_ABI_C13.nc', sample=0)
# Out:
# Loading data from ../data/kh_ABI_C13.nc (sample 0)

# %%
sharp_map = s1_map(img, 32, 16)

# %%
F, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(img, cmap='gray')
ax[1].imshow(sharp_map, cmap='gray')
